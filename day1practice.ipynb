# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
numbers = np.array([1, 2, 3, 4, 5])

print(numbers)
print("Mean:", np.mean(numbers))
print("Sum:", np.sum(numbers))
# Out:
# [1 2 3 4 5]
# Mean: 3.0
# Sum: 15

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Gender': ['Female', 'Male', 'Male'],
    'Study_Hours': [2, 3, 4],
    'Attendance': [90, 80, 95],
    'Grade': ['90', '85', '92']
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age  Gender  Study_Hours  Attendance Grade
# 0    Alice   25  Female            2          90    90
# 1      Bob   30    Male            3          80    85
# 2  Charlie   35    Male            4          95    92
