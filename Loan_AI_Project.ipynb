# %% [markdown]
# <a href="https://colab.research.google.com/github/klint-droid/machine-learning-projects/blob/main/Loan_AI_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = {
    "Income": [25000, 40000, 15000, 50000, 30000, 20000, 45000, 28000],
    "Loan_Amount": [10000, 20000, 8000, 25000, 12000, 9000, 22000, 11000],
    "Credit_Score": [700, 750, 600, 800, 720, 650, 780, 710],
    "Approved": [1, 1, 0, 1, 1, 0, 1, 1]
}

df = pd.DataFrame(data)
df
# Out:
#    Income  Loan_Amount  Credit_Score  Approved
# 0   25000        10000           700         1
# 1   40000        20000           750         1
# 2   15000         8000           600         0
# 3   50000        25000           800         1
# 4   30000        12000           720         1
# 5   20000         9000           650         0
# 6   45000        22000           780         1
# 7   28000        11000           710         1
